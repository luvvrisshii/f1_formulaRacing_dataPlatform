# %%
#Runnning first notebook
v = dbutils.notebook.run("1.ingest_circuits_file", 0, {"input_col_name":"NewTesting"})

# %%
print(v)
# Out:
# Successs

# %%
v = dbutils.notebook.run("ingest_constructor_file", 0)

# %%
v = dbutils.notebook.run("ingest_lap_times_file", 0)

# %%
v = dbutils.notebook.run("ingest_pitstops_file", 0)

# %%
v = dbutils.notebook.run("ingest_qualifying_files", 0)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-4206664330084497> in <cell line: 1>()
# ----> 1 v = dbutils.notebook.run("ingest_qualifying_files", 0)
#
# /databricks/python_shell/dbruntime/dbutils.py in run(self, path, timeout_seconds, arguments, _NotebookHandler__databricks_internal_cluster_spec)
#     202
#     203         def run(self, path, timeout_seconds, arguments={}, __databricks_internal_cluster_spec=None):
# --> 204             return self.entry_point.getDbutils().notebook()._run(
#     205                 path, timeout_seconds, arguments, __databricks_internal_cluster_spec,
#     206                 self.entry_point.getJobGroupId())
#
# /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# ...

# %%
v = dbutils.notebook.run("ingest_races_file", 0)

# %%
v = dbutils.notebook.run("ingestion_drivers_file", 0)

# %%
v = dbutils.notebook.run("ingestion_results_file", 0)
