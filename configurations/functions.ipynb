# %%
#current_time_ingestion
from pyspark.sql.functions import current_timestamp
def current_time_ingestion(input_df):
    output_df = input_df.withColumn("ingestion_date", current_timestamp())
    return output_df

# %%
#filename
def filename(inputpar):
    dbutils.widgets.text("input", inputpar)
    output = dbutils.widgets.get("input")
    return output
